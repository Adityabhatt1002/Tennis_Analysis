# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (2026.2.25)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (2.4.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (12.1.1)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (2.6.3)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from roboflow) (6.0.3)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: colorama in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=3 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Personal_Aditya\Vscode\Tennis_Project\.venv\Lib\site-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.15-py3-none-any.whl (94 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.8 MB 1.8 MB/s eta 0:00:22
#     --------------------------------------- 0.8/38.8 MB 1.8 MB/s eta 0:00:22
#    - -------------------------------------- 1.3/38.8 MB 1.7 MB/s eta 0:00:22
#    -- ------------------------------------- 2.1/38.8 MB 1.8 MB/s eta 0:00:20
#    -- ------------------------------------- 2.9/38.8 MB 2.2 MB/s eta 0:00:17
#    --- ------------------------------------ 3.7/38.8 MB 2.4 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.5/38.8 MB 2.7 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.5/38.8 MB 2.9 MB/s eta 0:00:12
#    ------ --------------------------------- 6.6/38.8 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.1/38.8 MB 3.1 MB/s eta 0:00:11
#    -------- ------------------------------- 8.1/38.8 MB 3.2 MB/s eta 0:00:10
#    -------- ------------------------------- 8.1/38.8 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 8.9/38.8 MB 3.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/38.8 MB 3.2 MB/s eta 0:00:10
#    ----------- ---------------------------- 10.7/38.8 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 11.8/38.8 MB 3.3 MB/s eta 0:00:09
#    ------------- -------------------------- 12.8/38.8 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/38.8 MB 3.5 MB/s eta 0:00:08
#    --------------- ------------------------ 14.9/38.8 MB 3.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 15.7/38.8 MB 3.6 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.5/38.8 MB 3.6 MB/s eta 0:00:07
#    ------------------ --------------------- 17.6/38.8 MB 3.7 MB/s eta 0:00:06
#    ------------------- -------------------- 18.6/38.8 MB 3.7 MB/s eta 0:00:06
#    -------------------- ------------------- 19.7/38.8 MB 3.8 MB/s eta 0:00:06
#    --------------------- ------------------ 20.4/38.8 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.5/38.8 MB 3.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.8/38.8 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 23.6/38.8 MB 3.9 MB/s eta 0:00:04
#    ------------------------- -------------- 24.6/38.8 MB 3.9 MB/s eta 0:00:04
#    -------------------------- ------------- 25.7/38.8 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/38.8 MB 4.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/38.8 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/38.8 MB 4.0 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/38.8 MB 4.0 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/38.8 MB 4.1 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/38.8 MB 4.1 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/38.8 MB 4.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.8/38.8 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.9/38.8 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 4.1 MB/s  0:00:09
# Downloading pi_heif-1.3.0-cp312-cp312-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/1.9 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.9 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 5.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.9 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.9 MB 5.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/9.9 MB 5.0 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.9 MB 5.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 4.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.5 MB/s  0:00:02
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#
#    ---- ----------------------------------- 1/9 [filetype]
#    -------- ------------------------------- 2/9 [tqdm]
#    ----------------- ---------------------- 4/9 [pi-heif]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#   Attempting uninstall: idna
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    -------------------------- ------------- 6/9 [idna]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ---------------------------------------- 9/9 [roboflow]
#
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.2 requests-toolbelt-1.0.0 roboflow-1.2.15 tqdm-4.67.3

# %% [markdown]
# GET DATASET

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TaoEBhY0FkapEMcPXZFg")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:20<00:00, 2531.46it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 1577.13it/s]

# %%
import shutil

# %%
shutil.move('tennis-ball-detection-6/train',
            'tennis-ball-detection-6/tennis-ball-detection-6/train',
            )

shutil.move('tennis-ball-detection-6/test',
            'tennis-ball-detection-6/tennis-ball-detection-6/test',
            )

shutil.move('tennis-ball-detection-6/valid',
            'tennis-ball-detection-6/tennis-ball-detection-6/valid',
            )
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'
